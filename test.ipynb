# %%
import mypackage as my

# %%
import pandas as pd
import ipystata 
import numpy as np
# Out:
# IPyStata is loaded in batch mode.

# %%
# import the Stata data in the form of .dta
df = pd.read_stata("m_MergedData.dta")
df.shape
# Out:
# (96127, 291)

# %%
df_copy1 = df.copy()
df_copy1 = df_copy1.sort_values(["permno", "time_avail_m"], ascending=[True, True])

# %%
df_test = pd.read_stata("Mon6m.dta")
df_test.shape
# Out:
# (96127, 295)

# %%
df_test = df_test.sort_values(["permno", "time_avail_m"], ascending=[True, True])

# %%
# gen sicCS   = sic
df_copy1["sicCS"] = df_copy1["sic"]
# replace sic = sicCRSP
# replace shrout = shrout/1000
# replace vol =  vol/10^4
df_copy1["shrout"] = df_copy1["shrout"] / 1000

# %%
# Converting units
df_copy1["vol"] = df_copy1["vol"] / 10e4

# %%
# common variables
# gen mve_c = (shrout * abs(prc)) // Common shares outstanding * Price
# gen ret2 = ret
# replace ret2 = 0 if ret2 ==.
df_copy1["mve_c"] = df_copy1["shrout"] * abs(df_copy1["prc"])
df_copy1["ret2"] = df_copy1["ret"]
df_copy1["ret2"] = df_copy1["ret2"].fillna(0)

# %%
df_test["sicCS"] = df_test["sic"]
df_test["shrout"] = df_test["shrout"] / 1000
df_test["vol"] = df_test["vol"] / 10e4
df_test["mve_c"] = df_test["shrout"] * abs(df_test["prc"])
df_test["ret2"] = df_test["ret"]
df_test["ret2"] = df_test["ret2"].fillna(0)

# %%
my.core.calMon6m(df_copy1)
# Out:
# 51971         NaN
# 51972         NaN
# 51973         NaN
# 51974         NaN
# 51975         NaN
#            ...
# 87689   -0.272165
# 87690   -0.244686
# 87691   -0.193847
# 87692    0.009133
# 87693    0.700799
# Name: ret2, Length: 96127, dtype: float32

# %%
my.core.calMon6m(df_test)
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 96122   -0.272165
# 96123   -0.244686
# 96124   -0.193847
# 96125    0.009133
# 96126    0.700799
# Name: ret2, Length: 96127, dtype: float32

# %%
e = my.core.calMon6m(df_copy1)

# %%
df_test["Mom6m_py"] = e.values
df_test["Mon6m_dif"] = df_test["Mom6m_py"] - df_test['Mom6m']

# %%
df_test["Mon6m_dif"] = df_test["Mon6m_dif"].fillna(0)
df_test["Mon6m_dif"]
# Out:
# 0        0.000000e+00
# 1        0.000000e+00
# 2        0.000000e+00
# 3        0.000000e+00
# 4        0.000000e+00
#              ...
# 96122   -5.960464e-08
# 96123   -7.450581e-08
# 96124    0.000000e+00
# 96125    6.705523e-08
# 96126   -1.192093e-07
# Name: Mon6m_dif, Length: 96127, dtype: float32

# %%
df_test["Mon6m_dif"].values
# Out:
# array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#         0.0000000e+00,  6.7055225e-08, -1.1920929e-07], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean = df_test["Mon6m_dif"].mean()

# %%
meanlist = [mean] * df_test.shape[0]

# %%
value = df_test["Mon6m_dif"].values

# %%
mean_squared_error(value, meanlist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f0e7a0fd56a6> in <module>
# ----> 1 mean_squared_error(value, meanlist)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     254         y_true, y_pred, multioutput)
#     255     check_consistent_length(y_true, y_pred, sample_weight)
# ...
